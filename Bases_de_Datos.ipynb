# %% [markdown]
# <a href="https://colab.research.google.com/github/clint00/Python-para-todos---CODEa-UNI/blob/curso_python/Bases_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Python – SQLite:**

# %%
import sqlite3 as sq
con = sq.connect("mina_01.sqlite3")
instruccion = "create table codea(id integer primary key AUTOINCREMENT, NOMBRE TEXT)"
con.execute(instruccion)
#con.commit()

#cur = con.execute(instruccion)

#cur.fetchall()
#cur.fetchone()
con.close()

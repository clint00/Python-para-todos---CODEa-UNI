# %% [markdown]
# <a href="https://colab.research.google.com/github/clint00/Python-para-todos---CODEa-UNI/blob/curso_python/Clases_y_Objetos_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Telefono:
    "Clase telefono"
    def __init__(self):
        pass
    def llamar_por_telefono(self):
        print("Llamando...")
    def colgar(self):
        print("Termino la llamada...")

class Camara:
    "clase camara fotografica"
    def __init__(self):
        pass
    def tomar_foto(self):
        print("tomando foto...")

class Reproductor:
    "Clase reproductor mp3"
    def __init__(self):
        pass
    def reproducir_mp3(self):
        print("reproduciendo musica")
    def reproducir_video(self):
        print("reproduciendo video")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
